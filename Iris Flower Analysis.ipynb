# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('IRIS.csv')

# %%
df
# Out:
#       ID  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...

# %%
df.head()
# Out:
#    ID  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 150 non-null    int64
#  1   Sepal Length (cm)  150 non-null    float64
#  2   Sepal Width (cm)   150 non-null    float64
#  3   Petal Length (cm)  150 non-null    float64
#  4   Petal Width (cm)   150 non-null    float64
#  5   Species            150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sns.set(style="whitegrid")

# %%
pairplot = sns.pairplot(df.drop(columns=["ID"]), hue="Species", markers=["o", "s", "D"])

# %%
print(df.head(50).describe())
# Out:
#              ID  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# count  50.00000           50.00000         50.000000          50.000000
# mean   25.50000            5.00600          3.418000           1.464000
# std    14.57738            0.35249          0.381024           0.173511
# min     1.00000            4.30000          2.300000           1.000000
# 25%    13.25000            4.80000          3.125000           1.400000
# 50%    25.50000            5.00000          3.400000           1.500000
# 75%    37.75000            5.20000          3.675000           1.575000
# max    50.00000            5.80000          4.400000           1.900000
#
#        Petal Width (cm)
# count          50.00000
# mean            0.24400
# std             0.10721
# min             0.10000
# 25%             0.20000
# 50%             0.20000
# 75%             0.30000
# max             0.60000

# %%
df.head(50)[df.head(50).Species=="Iris-setosa"]["Sepal Length (cm)"].mean()
# Out:
# 5.006

# %%
df.groupby("Species").mean().reset_index()
# Out:
#            Species     ID  Sepal Length (cm)  Sepal Width (cm)  \
# 0      Iris-setosa   25.5              5.006             3.418
# 1  Iris-versicolor   75.5              5.936             2.770
# 2   Iris-virginica  125.5              6.588             2.974
#
#    Petal Length (cm)  Petal Width (cm)
# 0              1.464             0.244
# 1              4.260             1.326
# 2              5.552             2.026

# %%
df.groupby("Species").std().reset_index()
# Out:
#            Species        ID  Sepal Length (cm)  Sepal Width (cm)  \
# 0      Iris-setosa  14.57738           0.352490          0.381024
# 1  Iris-versicolor  14.57738           0.516171          0.313798
# 2   Iris-virginica  14.57738           0.635880          0.322497
#
#    Petal Length (cm)  Petal Width (cm)
# 0           0.173511          0.107210
# 1           0.469911          0.197753
# 2           0.551895          0.274650

# %%
df.groupby("Species").median().reset_index()
# Out:
#            Species     ID  Sepal Length (cm)  Sepal Width (cm)  \
# 0      Iris-setosa   25.5                5.0               3.4
# 1  Iris-versicolor   75.5                5.9               2.8
# 2   Iris-virginica  125.5                6.5               3.0
#
#    Petal Length (cm)  Petal Width (cm)
# 0               1.50               0.2
# 1               4.35               1.3
# 2               5.55               2.0

# %%
sns.scatterplot(data=df, x="Sepal Length (cm)", y="Sepal Width (cm)", hue="Species", style="Species")
plt.title("Sepal Length vs. Sepal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %%
sns.scatterplot(data=df, x="Petal Length (cm)", y="Petal Width (cm)", hue="Species", style="Species")
plt.title("Petal Length vs.Petal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
# Out:
# Text(0, 0.5, 'Petal Width (cm)')

# %%
sns.scatterplot(data=df, x="Petal Length (cm)", y="Sepal Width (cm)", hue="Species", style="Species")
plt.title("Petal Length vs.Sepal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %%
sns.scatterplot(data=df, x="Sepal Length (cm)", y="Petal Width (cm)", hue="Species", style="Species")
plt.title("Sepal Length vs.Petal Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Petal Width (cm)")
# Out:
# Text(0, 0.5, 'Petal Width (cm)')

# %%
sns.scatterplot(data=df, x="Petal Length (cm)", y="Sepal Width (cm)", hue="Species", style="Species")
plt.title("Petal Length vs.Sepal Width")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %%
sns.scatterplot(data=df, x="Petal Width (cm)", y="Sepal Width (cm)", hue="Species", style="Species")
plt.title("Petal Width vs.Sepal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')
